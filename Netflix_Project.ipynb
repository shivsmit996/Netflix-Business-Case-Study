# %% [markdown]
# # NETFLIX PROJECT🎥

# %% [markdown]
# ![photo-1574375927938-d5a98e8ffe85.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# PROBLEM STATEMENT :
#
#
#
# *  The objective of this project is to help Netflix grow its business in different countries.
#
#
#
# *  To do this, we will analyze a dataset of Netflix content to gather business
# insights on different attributes of the content, such as the type of shows, ratings, duration, and release year.
#
# Ultimately, our goal is to help Netflix grow its business and become the leading streaming service in the world.

# %% [markdown]
# INSTALLATION of NUMPY

# %%
pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# INSTALLATION of PANDAS

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# IMPORTING BASIC LIBRARIES

# %%
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go
import plotly.figure_factory as ff
from google.colab import files
import io

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('netflix.csv', index_col = 'show_id')

# %%
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# ...

# %%
df.tail()
# Out:
#             type        title         director  \
# show_id
# s8803      Movie       Zodiac    David Fincher
# s8804    TV Show  Zombie Dumb              NaN
# s8805      Movie   Zombieland  Ruben Fleischer
# s8806      Movie         Zoom     Peter Hewitt
# s8807      Movie       Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# s8804                                                  NaN            NaN
# s8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#                 date_added  release_year rating   duration  \
# show_id
# s8803    November 20, 2019          2007      R    158 min
# s8804         July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 11)

# %% [markdown]
# The data consists of 8807 rows and 11 columns

# %%
df.size
# Out:
# 96877

# %%
df.columns
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# Here are the names of all the columns present in the Netflix dataset

# %%
df.dtypes
# Out:
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# Here are the datatypes of each column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8807 entries, s1 to s8807
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   object
#  1   title         8807 non-null   object
#  2   director      6173 non-null   object
#  3   cast          7982 non-null   object
#  4   country       7976 non-null   object
#  5   date_added    8797 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8803 non-null   object
#  8   duration      8804 non-null   object
#  9   listed_in     8807 non-null   object
#  10  description   8807 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 825.7+ KB

# %% [markdown]
# The data has 1 int64 column (release_year) and the rest are of object data type

# %%
df.isna().sum(axis=1)
# Out:
# show_id
# s1       1
# s2       1
# s3       1
# s4       3
# s5       1
#         ..
# s8803    0
# s8804    3
# s8805    0
# s8806    0
# s8807    0
# Length: 8807, dtype: int64

# %% [markdown]
# Missing Values Check

# %%
df.isna().sum()
# Out:
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# *  The dataframe has 2,634 missing values in the director column.
# *  The dataframe has 825 missing values in the cast column.
# *  The dataframe has 831 missing values in the country column.
# *  The dataframe has 10 missing values in the date_added column.
# *  The dataframe has 4 missing values in the rating column.
# *  The dataframe has 3 missing values in the duration column.

# %%
df['director'].fillna('Unkown director',inplace = True)
df['cast'].fillna('Unkown cast',inplace = True)
df['country'].fillna('Unkown country',inplace = True)
df['date_added'].fillna('Unkown date',inplace = True)
df['rating'].fillna('Unkown rating',inplace = True)
df['duration'].fillna('0',inplace = True)

df
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water  Unkown director
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans  Unkown director
# s5       TV Show           Kota Factory  Unkown director
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb  Unkown director
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast         country  \
# show_id
# s1                                             Unkown cast   United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...    South Africa
# ...

# %% [markdown]
# Filling all the missing values.

# %%
D = df.groupby('listed_in')['country'].value_counts()
D.tail(10)
# Out:
# listed_in  country
# Thrillers  Spain                                               1
#            United Kingdom, Australia, France, United States    1
#            United Kingdom, France, Germany, United States      1
#            United Kingdom, South Africa                        1
#            United Kingdom, United States                       1
#            United States, Hong Kong                            1
#            United States, India, France                        1
#            United States, Italy                                1
#            United States, Malta, France, United Kingdom        1
#            United States, Spain                                1
# Name: country, dtype: int64

# %% [markdown]
# Listing least 10 genres countrywise.

# %%
D = df.groupby('listed_in')['country'].value_counts()
D.head(10)
# Out:
# listed_in           country
# Action & Adventure  United States                    64
#                     United Kingdom, United States     8
#                     United Kingdom                    7
#                     Canada                            5
#                     United States, Canada             3
#                     United States, United Kingdom     3
#                     France, United States             2
#                     United States, Bulgaria           2
#                     United States, Germany            2
#                     Australia, United States          1
# Name: country, dtype: int64

# %% [markdown]
# Listing top 10 genres countrywise.

# %%
M =df['release_year'].value_counts()
M.head(10)
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
# 2021     592
# 2015     560
# 2014     352
# 2013     288
# 2012     237
# Name: release_year, dtype: int64

# %% [markdown]
# This means that the 10 most common release years for Netflix titles are:
#
# 1.  2018 -  1147
# 2.  2017 -  1032
# 3.  2019 -  1030
# 4.  2020 -  953
# 5.  2016 -  902
# 6.  2021 -  592
# 7.  2015 -  560
# 8.  2014 -  352
# 9.  2013 -  288
# 10. 2012 -  237
#
# It is interesting to note that the most recent release years have the most titles, which suggests that Netflix is constantly adding new content to its streaming service.

# %%
df.groupby('type').type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %% [markdown]
#  There are 6,131 movies and 2676 TV shows in the Netflix dataset.

# %%
x=df.groupby(['type'])['type'].count()
y=len(df)
r=((x/y)).round(2)

mf_ratio = pd.DataFrame(r).T

# %%
fig, ax = plt.subplots(1,1,figsize=(6.5, 2.5))

ax.barh(mf_ratio.index, mf_ratio['Movie'],
        color='#b20710', alpha=0.9, label='Male')
ax.barh(mf_ratio.index, mf_ratio['TV Show'], left=mf_ratio['Movie'],
        color='#221f1f', alpha=0.9, label='Female')

ax.set_xlim(0, 1)
ax.set_xticks([])
ax.set_yticks([])
#ax.set_yticklabels(mf_ratio.index, fontfamily='serif', fontsize=11)

# movie percentage
for i in mf_ratio.index:
    ax.annotate(f"{int(mf_ratio['Movie'][i]*100)}%",
                   xy=(mf_ratio['Movie'][i]/2, i),
                   va = 'center', ha='center',fontsize=40, fontweight='light', fontfamily='serif',
                   color='white')

    ax.annotate("Movie",
                   xy=(mf_ratio['Movie'][i]/2, -0.25),
                   va = 'center', ha='center',fontsize=15, fontweight='light', fontfamily='serif',
                   color='white')


for i in mf_ratio.index:
    ax.annotate(f"{int(mf_ratio['TV Show'][i]*100)}%",
                   xy=(mf_ratio['Movie'][i]+mf_ratio['TV Show'][i]/2, i),
                   va = 'center', ha='center',fontsize=40, fontweight='light', fontfamily='serif',
                   color='white')
    ax.annotate("TV Show",
                   xy=(mf_ratio['Movie'][i]+mf_ratio['TV Show'][i]/2, -0.25),
                   va = 'center', ha='center',fontsize=15, fontweight='light', fontfamily='serif',
                   color='white')


  # Title & Subtitle
fig.text(0.125,1.03,'Movie & TV Show distribution', fontfamily='serif',fontsize=15, fontweight='bold')
fig.text(0.125,0.92,'We see vastly more movies than TV shows on Netflix.',fontfamily='serif',fontsize=12)

for s in ['top', 'left', 'right', 'bottom']:
    ax.spines[s].set_visible(False)



#ax.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, -0.06))

# Removing legend due to labelled plot
ax.legend().set_visible(False)
plt.show()

# %% [markdown]
# The  chart shows that Movies make up about 70% of the content on Netflix, while TV Shows make up about 30% of the content. This suggests that Netflix is more focused on movies than TV shows.

# %%
df[(df['type']== 'Movie') & (df['release_year']== 2012)]
# Out:
#           type                                     title  \
# show_id
# s47      Movie                                Safe House
# s205     Movie                  Kyaa Super Kool Hain Hum
# s293     Movie                                   Quartet
# s309     Movie  American Masters: Inventing David Geffen
# s384     Movie                                Department
# ...        ...                                       ...
# s8461    Movie                                The Player
# s8498    Movie                             The Sapphires
# s8640    Movie                                   Tukaram
# s8662    Movie                           Unfinished Song
# s8779    Movie                               Yes or No 2
#
#                         director  \
# show_id
# s47              Daniel Espinosa
# s205                Sachin Yardi
# s293              Dustin Hoffman
# s309                  Susan Lacy
# s384             Ram Gopal Varma
# ...                          ...
# ...

# %% [markdown]
# The dataset is showing results of movies relased in the year 2012.

# %%
df[(df['type']== 'TV Show') & (df['country']== 'India')]
# Out:
#             type                               title         director  \
# show_id
# s5       TV Show                        Kota Factory  Unkown director
# s40      TV Show                        Chhota Bheem  Unkown director
# s51      TV Show                       Dharmakshetra  Unkown director
# s67      TV Show       Raja Rasoi Aur Anya Kahaniyan  Unkown director
# s70      TV Show      Stories by Rabindranath Tagore  Unkown director
# ...          ...                                 ...              ...
# s8174    TV Show                           Thackeray  Unkown director
# s8236    TV Show                         The Calling            Bumpy
# s8322    TV Show  The Golden Years with Javed Akhtar  Unkown director
# s8350    TV Show              The House That Made Me  Unkown director
# s8776    TV Show                     Yeh Meri Family  Unkown director
#
#                                                       cast country  \
# show_id
# ...

# %% [markdown]
# The dataset is showing results of TV Show of country India.

# %%
df.rating.value_counts()
# Out:
# TV-MA            3207
# TV-14            2160
# TV-PG             863
# R                 799
# PG-13             490
# TV-Y7             334
# TV-Y              307
# PG                287
# TV-G              220
# NR                 80
# G                  41
# TV-Y7-FV            6
# Unkown rating       4
# NC-17               3
# UR                  3
# 74 min              1
# 84 min              1
# 66 min              1
# Name: rating, dtype: int64

# %% [markdown]
#  Here is some of the information about different types of ratings:
#
# 1. The most common rating on Netflix is TV-MA, with 3,207 titles. This rating is for mature audiences only, and typically contains strong language, violence, and sexual content.
#
# 2. The second most common rating is TV-14, with 2,160 titles. This rating is for parents to be advised, and typically contains some material that may not be suitable for children under 14.
#
# 3. The third most common rating is TV-PG, with 863 titles. This rating is for parental guidance suggested, and typically contains some material that may not be suitable for younger children.
#
# 4. The fourth most common rating is R, with 799 titles. This rating is for restricted, and typically contains strong violence, sex, or language.
#
# 5. The fifth most common rating is PG-13, with 490 titles. This rating is for parents strongly cautioned, and typically contains some material that may be inappropriate for children under 13.
#
# The other ratings on Netflix are less common, but they are still used for some titles. These ratings include:
#
# * TV-Y7: This rating is for children ages 7 and up.
#
# * TV-Y: This rating is for children ages 2 and up.
#
# * PG: This rating is for parental guidance suggested.
#
# * TV-G: This rating is for general audiences.
# * NR: This rating means that the rating is not yet known.
#
# * Unknown rating: This rating means that the rating is unknown.
#
# * NC-17: This rating is for adults only, and typically contains strong violence, sex, or language.
#
# * UR: This rating means that the rating is unrated.

# %%
plt.figure(figsize=(12,10))
Release_Year = sns.countplot(y='release_year',data = df,order = df.release_year.value_counts().index[0:15])

# %%
df['listed_in'].value_counts().head(10)
# Out:
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
# Kids' TV                                            220
# Children & Family Movies                            215
# Children & Family Movies, Comedies                  201
# Documentaries, International Movies                 186
# Dramas, International Movies, Romantic Movies       180
# Name: listed_in, dtype: int64

# %%
plt.figure(figsize=(12,10))
Listed_In = sns.countplot(y='listed_in',data = df,order = df.listed_in.value_counts().index[0:15])

# %% [markdown]
# Here are the 10 most common genres on Netflix:
#
# *  The most common genre on Netflix is dramas, international movies, with 362 titles.
#
# * Documentaries are the second most common genre, with 359 titles.
#
# * Stand-up comedy is the third most common genre, with 334 titles.
#
# * Comedies, dramas, international movies is the fourth most common genre, with 274 titles.
#
# * Dramas, independent movies, international movies is the fifth most common genre, with 252 titles.
#
# * Kids' TV is the sixth most common genre, with 220 titles.
#
# * Children & family movies is the seventh most common genre, with 215 titles.
#
# * Children & family movies, comedies is the eighth most common genre, with 201 titles.
#
# * Documentaries, international movies is the ninth most common genre, with 186 titles.
#
# * Dramas, international movies, romantic movies is the tenth most common genre, with 180 titles.
#
# The other genres have fewer titles, but they are still popular on Netflix.
#
# The dataset could be used to learn more about the types of content that are available on Netflix. It could also be used to identify trends in the types of content that are becoming more popular on the streaming service.

# %%
rating_order_movie =  ['G', 'TV-Y', 'TV-G', 'PG', 'TV-Y7', 'TV-Y7-FV', 'TV-PG', 'PG-13', 'TV-14', 'R', 'NC-17', 'TV-MA']
rating_order_tv =  ['G', 'TV-Y', 'TV-G', 'TV-Y7', 'TV-Y7-FV', 'TV-PG', 'TV-14', 'R', 'TV-MA']
movie_rating = df['rating'].value_counts()[rating_order_movie]
tv_rating = df['rating'].value_counts()[rating_order_tv].fillna(0)

# %%
def rating_barplot(data, title, height, h_lim=None):
    fig, ax = plt.subplots(1,1, figsize=(15, 7))
    if h_lim :
        ax.set_ylim(0, h_lim)
    ax.bar(data.index, data,  color="#d0d0d0", width=0.6, edgecolor='black')

    color =  ['green',  'blue',  'orange',  'red']
    span_range = [[0, 2], [3,  6], [7, 8], [9, 11]]

    for idx, sub_title in enumerate(['Little Kids', 'Older Kids', 'Teens', 'Mature']):
        ax.annotate(sub_title,
                    xy=(sum(span_range[idx])/2 ,height),
                    xytext=(0,0), textcoords='offset points',
                    va="center", ha="center",
                    color="w", fontsize=16, fontweight='bold',
                    bbox=dict(boxstyle='round4', pad=0.4, color=color[idx], alpha=0.6))
        ax.axvspan(span_range[idx][0]-0.4,span_range[idx][1]+0.4,  color=color[idx], alpha=0.1)

    ax.set_title(f'Distribution of {title} Rating', fontsize=20, fontweight='bold', position=(0.5, 1.0+0.03))
    plt.show()

# %%
Movie_ratingwise = df[df['type']== 'Movie']
Movie_ratingwise.rating.value_counts()
# Out:
# TV-MA            2062
# TV-14            1427
# R                 797
# TV-PG             540
# PG-13             490
# PG                287
# TV-Y7             139
# TV-Y              131
# TV-G              126
# NR                 75
# G                  41
# TV-Y7-FV            5
# UR                  3
# NC-17               3
# Unkown rating       2
# 74 min              1
# 84 min              1
# 66 min              1
# Name: rating, dtype: int64

# %%
rating_barplot(movie_rating,'Movie', 1200)

# %%
Tv_Show_ratingwise = df[df['type']== 'TV Show']
Tv_Show_ratingwise.rating.value_counts()
# Out:
# TV-MA            1145
# TV-14             733
# TV-PG             323
# TV-Y7             195
# TV-Y              176
# TV-G               94
# NR                  5
# R                   2
# Unkown rating       2
# TV-Y7-FV            1
# 74 min              0
# PG-13               0
# PG                  0
# NC-17               0
# G                   0
# 84 min              0
# UR                  0
# 66 min              0
# Name: rating, dtype: int64

# %%
rating_barplot(tv_rating,'TV Show' , 700, 800)

# %%
df['tv_seasons']=np.where(df['type']=='TV Show', df['duration'].str[:-7]
                          .apply(lambda x: x.strip()), None)
df['tv_seasons'] = df['tv_seasons'].astype('float')

# %%
df.Minutes.astype(float)
df['Minutes'].astype(np.float).astype("Int64")
df.loc[:,["Minutes"]] = df.loc[:,["Minutes"]].apply(lambda x: x.astype('int64', errors ='ignore'))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8807 entries, s1 to s8807
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   object
#  1   title         8807 non-null   object
#  2   director      8807 non-null   object
#  3   cast          8807 non-null   object
#  4   country       8807 non-null   object
#  5   date_added    8807 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8807 non-null   object
#  8   duration      8807 non-null   object
#  9   listed_in     8807 non-null   object
#  10  description   8807 non-null   object
#  11  movie_mins    8800 non-null   float64
#  12  tv_seasons    2676 non-null   float64
#  13  Minutes       8807 non-null   int64
#  14  Unit          8804 non-null   object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 1.3+ MB

# %%
df['tv_seasons']= df['tv_seasons'].astype(np.float).astype("Int64")
df
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water  Unkown director
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans  Unkown director
# s5       TV Show           Kota Factory  Unkown director
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb  Unkown director
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast         country  \
# show_id
# s1                                             Unkown cast   United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...    South Africa
# ...

# %%
fig, ax = plt.subplots(2,1, figsize=(6,4))


ax[0].hist(df.Minutes, bins=13)
ax[0].set_title('Distribution of Movie Duration', fontsize=10)
ax[0].set_xlim(0,200)
ax[0].set_xticks(np.arange(0,200,25))
ax[0].set_xlabel('Duration in mins', fontsize=8)
ax[0].set_ylabel('Count of Movies', fontsize=8)

ax[1].hist(df.tv_seasons, bins=16)
ax[1].set_title('Distribution of Seasons in TV Shows', fontsize=10)
ax[1].set_xlim(1,10)
ax[1].set_xticks(np.arange(1,10,1))
ax[1].set_xlabel('Number of Seasons', fontsize=8)
ax[1].set_ylabel('Count of TV Shows', fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# Based on the following data from the Netflix dataset:
#
# * The average duration of a movie on Netflix is 112 minutes.
# * The most common duration for a movie on Netflix is 75-125 minutes.
# * The average number of seasons for a TV show on Netflix is 3.
# * The most common number of seasons for a TV show on Netflix is 1-2 seasons.
#
# These data suggest that Netflix tends to favor shorter movies and shorter TV shows. This may be because shorter titles are easier to watch and can be consumed in a single sitting. Additionally, shorter titles may be more affordable to produce.

# %%
df['Date'] = pd.to_datetime(df['date_added'], errors='coerce')
df
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water  Unkown director
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans  Unkown director
# s5       TV Show           Kota Factory  Unkown director
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb  Unkown director
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast         country  \
# show_id
# s1                                             Unkown cast   United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...    South Africa
# ...

# %%
df['Day'] = df['Date'].dt.strftime('%d')
df['Month'] = df['Date'].dt.strftime('%m')
df['Year'] = df['Date'].dt.strftime('%Y')
df
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water  Unkown director
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans  Unkown director
# s5       TV Show           Kota Factory  Unkown director
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb  Unkown director
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast         country  \
# show_id
# s1                                             Unkown cast   United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...    South Africa
# ...

# %% [markdown]
# Creating a seperate dataframe for Day,Month,Year from Date dataframe.

# %%
df['Year'] = df['Year'].astype(np.float).astype("Int64")

# %%
fig, ax = plt.subplots(1,2)

df.boxplot(column='release_year', ax=ax[0])
ax[0].set_title('Distribution of Release Year')

df.boxplot(column='Year', ax=ax[1])
ax[1].set_title('Distribution of Year_added')

plt.show()

# %% [markdown]
# The release year for content is concentrated in the range 2000-2021.
# The year of adding content is concentrated in the range 2015-2021.
#
# This data suggests that Netflix has been adding content at a steady pace in recent years. This may be because Netflix is expanding its library of content to attract more subscribers. Additionally, Netflix may be acquiring more content from other studios and networks.

# %%
df = df.drop(['date_added'], axis=1)
df
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water  Unkown director
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans  Unkown director
# s5       TV Show           Kota Factory  Unkown director
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb  Unkown director
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast         country  \
# show_id
# s1                                             Unkown cast   United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...    South Africa
# ...

# %%
df['count']=1 #helper column
data = df.groupby('country')['count'].sum().sort_values(ascending=False)[:10]
data =data.drop('Unkown country')
data
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Name: count, dtype: int64

# %%
color_map = ['#f5f5f1' for _ in range(10)]
color_map[0] = color_map[1]= color_map[2] = '#b20710'
fig,ax = plt.subplots(1,1,figsize=(12,6))
#Annotating the figure
ax.bar(data.index,data,width=0.5,edgecolor='darkgray',linewidth=0.6,color=color_map)
for i in data.index:
    ax.annotate(f"{data[i]}",xy=(i,data[i]+100),va='center',ha='center',fontweight='light',fontfamily='serif')
for s in ['top','left','right']:
    ax.spines[s].set_visible(False)




#Adding text
fig.text(0.125,1,'Top 10 countries on Netflix',fontsize=15,fontweight='bold',fontfamily='serif')
fig.text(0.125,0.95,'The three most frequent countries have been highlighted.',fontsize=10,fontweight='light',fontfamily='serif')
fig.text(1.1, 1.01, 'Insight', fontsize=15, fontweight='bold', fontfamily='serif')
fig.text(1.1, 0.67, '''
Here we see that US is major content
producers for Netflix, and on second
we have India after UK and so on.
Netflix being a US Company, it makes
sense that they major producers.
'''
         , fontsize=12, fontweight='light', fontfamily='serif')
ax.grid(axis='y', linestyle='-', alpha=0.5)

# %%
df_tv = df[df["type"] == "TV Show"]
df_movies = df[df["type"] == "Movie"]

# %%
df_content = df['Year'].value_counts().reset_index().rename(columns = {
    'Year' : 'count', 'index' : 'Year'}).sort_values('Year')
df_content['percent'] = df_content['count'].apply(lambda x : 100*x/sum(df_content['count']))


df_tv1 = df_tv['Year'].value_counts().reset_index().rename(columns = {
    'Year' : 'count', 'index' : 'Year'}).sort_values('Year')
df_tv1['percent'] = df_tv1['count'].apply(lambda x : 100*x/sum(df_tv1['count']))


df_movies1 = df_movies['Year'].value_counts().reset_index().rename(columns = {
    'Year' : 'count', 'index' : 'Year'}).sort_values('Year')
df_movies1['percent'] = df_movies1['count'].apply(lambda x : 100*x/sum(df_movies1['count']))

t1 = go.Scatter(x=df_movies1['Year'], y=df_movies1["count"], name="Movies", marker=dict(color="purple"))
t2 = go.Scatter(x=df_tv1['Year'], y=df_tv1["count"], name="TV Shows", marker=dict(color="blue"))
t3 = go.Scatter(x=df_content['Year'], y=df_content["count"], name="Total Contents", marker=dict(color="red"))

data = [t1, t2, t3]

layout = go.Layout(title="Content added over the years", legend=dict(x=0.1, y=1.1, orientation="h"))
fig = go.Figure(data, layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The number of movie and TV show releases on Netflix has increased drastically since 2015, with 2018 marking the highest number of releases.
#
# This sentence highlights the following key points from the data:
#
# *  The number of releases has increased steadily from 2005 to 2015.
#
# * The number of releases surged drastically from 2015 to 2018.
#
# * 2018 had the highest number of releases, with 1147 titles.
#
# This data suggests that Netflix has been increasing its investment in original content in recent years. This may be because Netflix is trying to attract new subscribers and keep existing subscribers engaged. Additionally, Netflix may be responding to the increasing competition from other streaming services.

# %%
df_content = df[['Month']].value_counts().reset_index().rename(columns = {
    0 : 'count'}).sort_values('Month')
df_content['percent'] = df_content['count'].apply(lambda x : 100*x/sum(df_content['count']))


df_tv2 = df_tv[['Month']].value_counts().reset_index().rename(columns = {
    0 : 'count'}).sort_values('Month')
df_tv2['percent'] = df_tv2['count'].apply(lambda x : 100*x/sum(df_tv2['count']))

df_movies2 = df_movies[['Month']].value_counts().reset_index().rename(columns = {
    0 : 'count'}).sort_values('Month')
df_movies2['percent'] = df_movies2['count'].apply(lambda x : 100*x/sum(df_movies2['count']))

t1 = go.Scatter(x=df_movies2['Month'], y=df_movies2["count"], name="Movies", marker=dict(color="#a678de"))
t2 = go.Scatter(x=df_tv2['Month'], y=df_tv2["count"], name="TV Shows", marker=dict(color="#6ad49b"))
t3 = go.Scatter(x=df_content['Month'], y=df_content["count"], name="Total Contents", marker=dict(color="Brown"))


data = [t1, t2, t3]

layout = go.Layout(title="Content added over the years", legend=dict(x=0.1, y=1.1, orientation="h"))
fig = go.Figure(data, layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The growth in content on Netflix is highest in the first three months (Q1) and the last three months (Q4) of the year, with February having the least number of content additions.

# %%
plt.figure(figsize=(15,5))
sns.barplot(x = df_movies["listed_in"].value_counts().head(10).index,
            y = df_movies["listed_in"].value_counts().head(10).values,palette="tab10")
plt.xticks(rotation=80)
plt.title("Top10 Genre in Movies",fontweight="bold")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.barplot(x = df_tv["listed_in"].value_counts().head(10).index,
            y = df_tv["listed_in"].value_counts().head(10).values,palette="dark")
plt.xticks(rotation=80)
plt.title("Top10 Genre in TV Shows",fontweight="bold")
plt.show()

# %%
import signal
import sys
import time
import threading

def signal_handler(signal, frame):
    print('You pressed Ctrl+C!')
    sys.exit(0)

signal.signal(signal.SIGINT, signal_handler)
print('Press Ctrl+C')
forever = threading.Event()
forever.wait()

# %%
df['cast_name'] = df['cast'].apply(lambda x :  x.replace(' ,',',').replace(', ',',').split(','))
cast_count = []
for i in df['cast_name']: cast_count += i

cast_dict = dict((i, cast_count.count(i)) for i in cast_count)

df_cast_count = pd.DataFrame(cast_dict.values(),cast_dict.keys()).reset_index().sort_values(0,ascending=False).rename(
    columns = {'index' : 'cast_name', 0 : 'count'}).iloc[1:21]

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='cast_name',y='count',data=df_cast_count,palette="deep")
plt.title("Top20 Artist on Netflix",fontweight="bold")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# *   We can see that top 4 artist are indians.
# *   Out of top 20 there are 13 indian artists.

# %%
df['listed_in'] = df['listed_in'].astype('str').apply(
    lambda x: x.split(', '))

# %%
country_genre_df = df.explode('listed_in').drop_duplicates()

# %%
top_20 = df.country.value_counts().reset_index()
top_20 = top_20.loc[:20,'index'].to_list()
top_20.remove('Unkown country')
top_20_df = country_genre_df.loc[country_genre_df['country'].isin(top_20)]

# %%
def custom_agg(x):
  return x.nunique()

data = pd.pivot_table(top_20_df, index = top_20_df['listed_in'],
                      columns = top_20_df['country'],
                      values = 'Year', aggfunc=custom_agg)

# %%
import matplotlib
plt.figure(figsize=(8,8))
ax = sns.heatmap(data, annot=True, fmt=".0f",
                 norm=matplotlib.colors.LogNorm(vmin=data.min().min(),
                                                vmax=data.max().max()))
ax.set(xlabel="Countries", ylabel="Categories", title='Countries v/s Genres');

# %% [markdown]
# 1.   Action & Adventure, Children & Family Movies, Comedies, Dramas, International Movies & TV Shows, TV Dramas, and Thrillers are popular genres across countries.
#
# 2. Korean TV shows are popular in Korea.
#
# 3. British TV shows are popular in the UK.
#
# 4. Anime features and Anime series are popular in Japan.
#
# 5. Spanish TV shows are popular in Argentina, Mexico, and Spain.
#
# 6. The United States and UK have a good mix of almost all genres.

# %%
data = pd.pivot_table(top_20_df, index = top_20_df['rating'],
                      columns = top_20_df['country'],
                      values = 'Year', aggfunc=custom_agg)

#Heatmap using Seaborn

plt.figure(figsize=(12,6))
ax = sns.heatmap(data, annot=True, fmt=".0f",
                 norm=matplotlib.colors.LogNorm(vmin=data.min().min(),
                                                vmax=data.max().max()))
ax.set(xlabel="Countries", ylabel="Ratings", title='Countries v/s Ratings');

# %% [markdown]
# 1. Netflix has a disproportionate amount of adult content (TV-MA & TV-14) across all countries.
#
# 2. India has a higher proportion of TV-PG content than other countries.
#
# 3. Only the US, Canada, UK, France, and Japan have content for young audiences (TV-Y & TV-Y7).
#
# 4. There is scarce content for general audiences (TV-G & G) across all countries except the US.

# %%
df[df['cast'].str.contains('Salman Khan')]
# Out:
#      show_id   type                                     title  \
# 1441   s1442  Movie                             Hello Brother
# 1674   s1675  Movie                                 Bodyguard
# 2339   s2340  Movie                      Prem Ratan Dhan Payo
# 2545   s2546  Movie                           Andaz Apna Apna
# 2734   s2735  Movie                        Kuch Kuch Hota Hai
# 2756   s2757  Movie                                 Paharganj
# 2957   s2958  Movie                       Hum Aapke Hain Koun
# 2969   s2970  Movie                     Together For Eternity
# 4729   s4730  Movie                     Main aurr Mrs. Khanna
# 5718   s5719  Movie                           Mumbai Cha Raja
# 6440   s6441  Movie                            Chal Mere Bhai
# 7022   s7023  Movie                      Hum Saath-Saath Hain
# 7109   s7110  Movie  Jaan-E-Mann: Let's Fall in Love... Again
# 7144   s7145  Movie                                    Judwaa
# ...

# %% [markdown]
# The dataset shows all movies of actor Salman Khan.

# %%
Cast_Name = df.loc[df['director']== 'Anees Bazmee']
Cast_Name
# Out:
#      show_id   type      title      director  \
# 1946   s1947  Movie    Welcome  Anees Bazmee
# 4736   s4737  Movie  Thank You  Anees Bazmee
# 5183   s5184  Movie  Mubarakan  Anees Bazmee
# 6588   s6589  Movie  Deewangee  Anees Bazmee
# 7590   s7591  Movie   No Entry  Anees Bazmee
# 7837   s7838  Movie      Ready  Anees Bazmee
#
#                                                    cast country  \
# 1946  Akshay Kumar, Katrina Kaif, Nana Patekar, Anil...   India
# 4736  Akshay Kumar, Bobby Deol, Sonam Kapoor, Irrfan...   India
# 5183  Anil Kapoor, Arjun Kapoor, Ileana D'Cruz, Athi...   India
# 6588  Ajay Devgn, Akshaye Khanna, Urmila Matondkar, ...   India
# 7590  Anil Kapoor, Salman Khan, Fardeen Khan, Bipash...   India
# 7837  Salman Khan, Asin, Paresh Rawal, Mahesh Manjre...   India
#
#               date_added  release_year rating duration  \
# 1946  September 28, 2020          2007  TV-PG  149 min
# 4736      August 2, 2018          2011  TV-14  131 min
# ...

# %% [markdown]
# The dataset shows details of director Anees Bazmee.

# %%
df[(df['type']== 'Movie') & (df['rating']== 'R') & (df['release_year'] >= 2012)]
# Out:
#      show_id   type              title  \
# 46       s47  Movie         Safe House
# 81       s82  Movie               Kate
# 133     s134  Movie            Chappie
# 141     s142  Movie         Extraction
# 178     s179  Movie      The Interview
# ...      ...    ...                ...
# 8730   s8731  Movie  Where's the Money
# 8731   s8732  Movie  While We're Young
# 8751   s8752  Movie    Wish I Was Here
# 8754   s8755  Movie             Wolves
# 8765   s8766  Movie                 XX
#
#                                                director  \
# 46                                      Daniel Espinosa
# 81                                Cedric Nicolas-Troyan
# 133                                      Neill Blomkamp
# 141                                    Steven C. Miller
# 178                           Evan Goldberg, Seth Rogen
# ...                                                 ...
# 8730                                    Scott Zabielski
# ...

# %% [markdown]
# The dataset shows all the movies that are rated 'R' and released after the year '2012'.

# %%
df['Minutes'].max()
# Out:
# 312

# %%
Movie_With_Long_Duration = df.nlargest(5, "Minutes")[['title','duration']]

# %%
Movie_With_Long_Duration
# Out:
#                             title duration
# 4253   Black Mirror: Bandersnatch  312 min
# 717   Headspace: Unwind Your Mind  273 min
# 2491       The School of Mischief  253 min
# 2487               No Longer kids  237 min
# 2484           Lock Your Girls In  233 min

# %% [markdown]
# The maximum duration of content is 312 min.

# %%
df['release_year'].min()
# Out:
# 1925

# %% [markdown]
# The dataset has oldest movie added of year 1925.

# %%
df['release_year'].max()
# Out:
# 2021

# %% [markdown]
# The dataset has newest movie added of year 2021.

# %%
TV_Show = df[df['type']== 'TV Show']
TV_Show_directorwise = TV_Show.director.value_counts().head(10)

TV_Show_directorwise = pd.DataFrame(TV_Show_directorwise)

TV_Show_directorwise.drop('Unkown director')
# Out:
#                      director
# Alastair Fothergill         3
# Hsu Fu-chun                 2
# Iginio Straffi              2
# Shin Won-ho                 2
# Rob Seidenglanz             2
# Ken Burns                   2
# Stan Lathan                 2
# Quek Shio-chuan             1
# Peter Ho                    1

# %% [markdown]
# This table shows the top 9 directors in TV Show with the most Netflix titles. Alastair Fothergill has the most titles with 3,
#
# followed by Hsu Fu-chun, Iginio Straffi, Shin Won-ho, Rob Seidenglanz, Ken Burns, and Stan Lathan, who all have 2 titles each.

# %%
Movie = df[df['type']== 'Movie']
Movie_directorwise = Movie.director.value_counts().head(10)

Movie_directorwise = pd.DataFrame(Movie_directorwise)

Movie_directorwise.drop('Unkown director')
# Out:
#                         director
# Rajiv Chilaka                 19
# Raúl Campos, Jan Suter        18
# Suhas Kadav                   16
# Marcus Raboy                  15
# Jay Karas                     14
# Cathy Garcia-Molina           13
# Martin Scorsese               12
# Jay Chapman                   12
# Youssef Chahine               12

# %% [markdown]
# This table shows the top 10 directors in Movies with the most Netflix titles. Rajiv Chilaka has the most titles with 19 Movie titles, followed by Raúl Campos and Jan Suter with 18 Movie titles, Suhas Kadav with 16 Movie titles , Marcus Raboy with 15 Movie titles, Jay Karas with 14 Movie titles, Cathy Garcia-Molina with 13 Movie titles, Martin Scorsese, Jay Chapman, and Youssef Chahine, who all have 12 titles each.

# %% [markdown]
#    # Business Insights

# %% [markdown]
# Here are some business insights that can be drawn from the range of attributes :
#
# 1. Type of show: Netflix's content library is dominated by movies, which account for about 70% of the titles. This is likely because movies are typically shorter and easier to produce than TV shows, and they can be more easily marketed to a global audience.
#
# 2. Release year: The release year for shows is concentrated in the range 2000-2021. This suggests that Netflix is constantly adding new content to its library, and that it is also investing in older content that may have been overlooked by other streaming services.
#
# 3. Year of adding shows: The year of adding shows is concentrated in the range 2015-2021. This suggests that Netflix has been expanding its content library rapidly in recent years, and that it is likely to continue to do so in the future.
#
# 4. Movie duration: The movie duration range of 50-150 minutes is consistent with the typical length of a feature film. This suggests that Netflix is not trying to compete with traditional TV networks by offering shorter, more episodic content
#
# 5. TV show duration: The TV show duration range of 1-3 seasons is also consistent with the typical length of a TV series. This suggests that Netflix is not trying to compete with traditional cable networks by offering longer, serialized content.
#
# 6. Countries: The fact that only 23 countries have more than 50 movie titles and only 11 countries have more than 50 TV shows suggests that Netflix is still heavily focused on the US market. However, the company is clearly expanding its international presence, and it is likely to continue to do so in the future.
#
# 7. Ratings: The 12 different kinds of ratings based on the relevance of the content for different age-groups suggest that Netflix is taking a proactive approach to ensuring that its content is accessible to a wide range of viewers.
#
# 8. Actors and directors: The number of actors and directors in the dataset suggests that Netflix is working with a large and diverse pool of creative talent. This is likely to be a key factor in the company's ability to continue to produce high-quality content.
#
# By analyzing this data, Netflix can gain valuable insights into its content library and how it can be improved.

# %% [markdown]
# VISUAL ANALYSIS :
#
# 1. The number of movies and TV shows released on Netflix has increased significantly since 2015.
#
# 2. 2018 marked the highest number of releases.
#
# 3. The last quarter of the year (October-December) has more shows being added than the other months of the year.
#
# 4. This could be due to the festive seasons in the United States and India, which typically fall in this time period.

# %% [markdown]
# Type of content across Countries:
#
# 1. The United States has the most movie and TV show listings.
#
# 2. India, the United Kingdom, Canada, and France also have a significant number of movie and TV show listings.
#
# 3. The United States and the United Kingdom have a good mix of almost all genres.
#
# 4. Other countries tend to specialize in certain genres, such as Korean TV shows (Korea), British TV Shows (UK), Anime features and Anime series (Japan), and Spanish TV Shows (Argentina, Mexico and Spain).

# %% [markdown]
# # Recommendation

# %% [markdown]
# 1. Add more data about user preferences. This would allow Netflix to better recommend content to users.
#
# 2. Netflix could collect data about what users have watched in the past, what genres they like, and what ratings they have given to movies and TV shows.
#
# 3. Netflix can expand its target audience by adding more content for young/general audiences, such as family and children shows.
#
# 4. Netflix can increase its business in countries other than the United States and the United Kingdom by adding more variety of content.
#
# 5. Netflix can create country-specific genres to appeal to specific audiences in different countries.
#
# 6. Netflix can promote and acquire customers in top 5 countries by partnering with local businesses.
#
# 7. Netflix can add more content in next 5 countries to appeal to a wider audience.
#
# 8. December & January are definitely the best months for new content.

# %% [markdown]
# Netflix started as DVD rentals, and now they have an audience of over 150m people - this is their story...
